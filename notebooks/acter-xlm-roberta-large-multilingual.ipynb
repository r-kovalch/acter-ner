# %% [markdown]
# <a href="https://colab.research.google.com/github/Reennon/acter-ner/blob/main/notebooks/acter-xlm-roberta-large-multilingual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Reennon/acter-ner
# Out:
# Cloning into 'acter-ner'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 117 (delta 65), reused 61 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 2.35 MiB | 5.83 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# !git clone https://github.com/AylaRT/ACTER
# Out:
# Cloning into 'ACTER'...
# remote: Enumerating objects: 5448, done.
# remote: Counting objects: 100% (5448/5448), done.
# remote: Compressing objects: 100% (3304/3304), done.
# remote: Total 5448 (delta 2684), reused 4893 (delta 2132), pack-reused 0 (from 0)
# Receiving objects: 100% (5448/5448), 11.90 MiB | 15.02 MiB/s, done.
# Resolving deltas: 100% (2684/2684), done.

# %%
# %cd /content/ACTER
# Out:
# /content/ACTER

# %%
# %cd /content/acter-ner/term_extractor
# Out:
# /content/acter-ner/term_extractor

# %%
ls
# Out:
# combine_corpora-en-fr-nl.sh  configs/              preprocess_acter.py  train_model.py
# combine_corpora-en-fr.sh     dataset_processor.py  test_full.tsv        train_spacy_model.py
# combine_corpora.sh           output/               train_full.tsv       Untitled.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !git checkout main
# Out:
# Already on 'main'
# Your branch is up to date with 'origin/main'.

# %%
# !bash combine_corpora-en-fr-nl.sh
# Out:
# Processing directory: /content/ACTER/en/corp/annotated/annotations/sequential_annotations/iob_annotations/without_named_entities
# Processed /content/ACTER/en/corp/annotated/annotations/sequential_annotations/iob_annotations/without_named_entities/corp_en_08_seq_terms.tsv: 163 sentences
# Processed /content/ACTER/en/corp/annotated/annotations/sequential_annotations/iob_annotations/without_named_entities/corp_en_12_seq_terms.tsv: 278 sentences
# Processed /content/ACTER/en/corp/annotated/annotations/sequential_annotations/iob_annotations/without_named_entities/corp_en_06_seq_terms.tsv: 364 sentences
# Processed /content/ACTER/en/corp/annotated/annotations/sequential_annotations/iob_annotations/without_named_entities/corp_en_07_seq_terms.tsv: 334 sentences
# Processed /content/ACTER/en/corp/annotated/annotations/sequential_annotations/iob_annotations/without_named_entities/corp_en_19_seq_terms.tsv: 56 sentences
# ...

# %%
# !spacy convert --converter iob train_full.tsv output && \
  spacy convert --converter iob test_full.tsv output
# Out:
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (30230 documents): output/train_full.spacy
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (7558 documents): output/test_full.spacy

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !mkdir input_data -p && \
  mkdir /content/drive/MyDrive/ucu/ner/output-xlm-roberta-large-en-fr-nl -p && \
  mv output/train_full.spacy input_data/train_full.spacy && \
  mv output/test_full.spacy input_data/test_full.spacy

# %%
# !pip install 'spacy[transformers]' -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.2/756.2 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 27.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# combine_corpora-en-fr-nl.sh  dataset_processor.py  test_full.tsv	 Untitled.ipynb
# combine_corpora-en-fr.sh     input_data		   train_full.tsv
# combine_corpora.sh	     output		   train_model.py
# configs			     preprocess_acter.py   train_spacy_model.py

# %%
# !spacy train configs/config_xlm_roberta_large_multilingual.cfg --gpu-id 0 --output /content/drive/MyDrive/ucu/ner/output-xlm-roberta-large-en-fr-nl
# Out:
# ℹ Saving to output directory:
# /content/drive/MyDrive/ucu/ner/output-xlm-roberta-large-en-fr-nl
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 191kB/s]
# config.json: 100% 616/616 [00:00<00:00, 4.78MB/s]
# sentencepiece.bpe.model: 100% 5.07M/5.07M [00:00<00:00, 38.5MB/s]
# tokenizer.json: 100% 9.10M/9.10M [00:00<00:00, 12.2MB/s]
# 2025-04-06 15:34:21.315146: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-06 15:34:21.334595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
from google.colab import runtime
runtime.unassign()
